# %% [markdown]
# # 🎯 KOICA TAG v3.1 - 예시 복사 방지 강화
#
# **🔧 v3.1 핵심 개선**:
# 1. ✅ **예시 복사 방지**: 형식 가이드로 변경, 구체적 내용 제거
# 2. ✅ **명시적 지시 강화**: "태양광, 디젤 등 예시 내용 복사 금지"
# 3. ✅ **검증 로직 추가**: 예시 키워드 검출 및 경고
# 4. ✅ **실제 문서 강조**: 참고 문서에서 발견한 내용만 사용
#
# **해결된 문제**:
# - ❌ 예시 내용(태양광, 디젤) 복사 → ✅ 실제 PDF 문서 분석
# - ❌ 엉뚱한 내용 출력 → ✅ 문서에 있는 내용만 분석

# %%
# 1️⃣ 패키지 설치
print("📦 패키지 설치 중...")
# !pip install -q pdfplumber gradio sentence-transformers huggingface-hub
# !pip install -q llama-cpp-python --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu121
# !pip install -q pandas numpy
print("✅ 설치 완료!\n")

# %%
# 2️⃣ GitHub에서 최신 v3.1 코드 다운로드 및 실행
print("📥 v3.1 코드 다운로드 중...")
# !wget -q https://raw.githubusercontent.com/amnotyoung/autotag/claude/fix-solar-analysis-rainy-season-011CUv6NG6frc4X4LBy2vEBd/autotag.py
print("✅ 다운로드 완료!\n")

print("🚀 KOICA TAG v3.1 시작...\n")
# %run autotag.py

# %% [markdown]
# ---
#
# ## ℹ️ 사용 방법
#
# 1. **위 2개 셀을 순서대로 실행** (Shift + Enter)
# 2. **GPU 런타임 설정**: Runtime → Change runtime type → GPU
# 3. Gradio 인터페이스가 열리면 **PDF 업로드**
# 4. 자동으로 TAG 분석 시작 (5-10분)
# 5. 분석 완료 후 **TXT/HTML 다운로드** 가능
#
# ## 🔧 v3.1 개선사항
#
# - **예시 복사 방지**: AI가 형식 예시를 그대로 복사하던 문제 해결
# - **실제 문서 분석**: 업로드한 PDF의 실제 내용만 분석
# - **검증 강화**: 예시 키워드(태양광, 디젤 등) 검출 시 콘솔에 경고
#
# ## ⚠️ 중요사항
#
# - **GPU 런타임 필수**: Runtime → Change runtime type → **GPU** 선택
# - 첫 실행 시 Llama 3.1 70B 모델 다운로드로 **10-20분** 소요 (모델 크기: ~40GB)
# - 분석 시간: 30-50페이지 기준 약 **5-10분**
# - **고성능 GPU 필요**: 70B 모델은 최소 40GB VRAM 권장 (A100 또는 유사한 GPU)
#
# ## 🐛 문제 해결
#
# | 문제 | 해결방법 |
# |------|----------|
# | GPU 에러 | Runtime → Change runtime type → GPU 확인 |
# | 패키지 설치 에러 | 첫 번째 셀 다시 실행 |
# | 메모리 부족 | Runtime → Restart runtime 후 재시작 |
# | 타임아웃 | PDF 파일이 너무 크면 50페이지 이하로 분할 |
